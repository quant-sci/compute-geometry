# %%
from minimum_circle import ComputeMinimumCircle

if __name__ == "__main__":
    circle_computer = ComputeMinimumCircle()
    sizes = [20, 200, 2000, 200000, 2000000]
    circle_computer.plot_min_circle_random(sizes)
# Out:
# MinCircle Center/Radius: [0.3293079779907297, -0.7859853496205972] / 2.458080197488558
# Heuristic Center/Radius: [0.45670407313387323, -0.8863465762080791] / 2.61708743584473
# MinCircle Center/Radius: [-0.18801935973431938, 0.5089530106674655] / 2.87542599258609
# Heuristic Center/Radius: [-0.3050134641819786, 0.44029147398728175] / 2.948846907581997
# MinCircle Center/Radius: [0.178237632562174, -0.758068000012106] / 3.878131410931514
# Heuristic Center/Radius: [0.2810133541779643, -0.7789051880882932] / 3.9789167744793255
# MinCircle Center/Radius: [-0.11638294867407827, 0.20513912843542234] / 4.853993744369679
# Heuristic Center/Radius: [-0.4935561138318145, -0.789661227856804] / 5.901365694031861
# MinCircle Center/Radius: [-0.048294713897807304, -0.35779966020690174] / 5.6561207243597025
# Heuristic Center/Radius: [0.7309907260144958, 0.684053729283389] / 6.823240550197124
